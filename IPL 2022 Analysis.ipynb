# %% [markdown]
# ## Every sporting event today generates a lot of data about the game, which is used to analyze the performance of players, teams, and every event of the game. So the use of data science is in every sport today. Currently, IPL 2022 is one of the popular sporting events being held in India. So, if you want to learn how to analyze IPL 2022, this article is for you. In this article, I will take you through the task of IPL 2022 analysis using Python.
# ![ipl-ads.png](attachment:ipl-ads.png)

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv(r'D:\my portfolio\files\ipl_2022.csv')
df.head(10)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5         6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6         7  March 31,2022                     Brabourne Stadium, Mumbai
# 7         8   April 1,2022                      Wankhede Stadium, Mumbai
# 8         9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9        10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
# 5   Banglore    Kolkata  Group    Banglore         Field               128
# 6    Chennai    Lucknow  Group     Lucknow         Field               210
# 7    Kolkata     Punjab  Group     Kolkata         Field               137
# 8     Mumbai  Rajasthan  Group      Mumbai         Field               193
# 9      Delhi    Gujarat  Group       Delhi         Field               171
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
# 5               10                132                 7     Banglore  Wickets
# 6                7                211                 4      Lucknow  Wickets
# 7               10                141                 4      Kolkata  Wickets
# 8                8                170                 8    Rajasthan     Runs
# 9                6                157                 9      Gujarat     Runs
#
#    margin player_of_the_match           top_scorer  highscore  \
# 0       6         Umesh Yadav             MS Dhoni         50
# 1       4       Kuldeep Yadav         Ishan Kishan         81
# 2       5         Odean Smith       Faf du Plessis         88
# 3       5      Mohammed Shami         Deepak Hooda         55
# 4      61        Sanju Samson        Aiden Markram         57
# 5       3   Wanindu Hasaranga  Sherfane Rutherford         28
# 6       6          Evin Lewis      Quinton de Kock         61
# 7       6         Umesh Yadav        Andre Russell         70
# 8      23         Jos Buttler          Jos Buttler        100
# 9      14     Lockie Ferguson         Shubman Gill         84
#
#         best_bowling best_bowling_figure
# 0       Dwayne Bravo               3--20
# 1      Kuldeep Yadav               3--18
# 2     Mohammed Siraj               2--59
# 3     Mohammed Shami               3--25
# 4   Yuzvendra Chahal               3--22
# 5  Wanindu Hasaranga               4--20
# 6       Ravi Bishnoi               2--24
# 7        Umesh Yadav               4--23
# 8     Jasprit Bumrah               3--17
# 9    Lockie Ferguson               4--28

# %%
df.describe(include='all')
# Out:
#          match_id        date                               venue     team1  \
# count   46.000000          46                                  46        46
# unique        NaN          37                                   4         8
# top           NaN  May 1,2022  Dr DY Patil Sports Academy, Mumbai  Banglore
# freq          NaN           2                                  14        10
# mean    23.500000         NaN                                 NaN       NaN
# std     13.422618         NaN                                 NaN       NaN
# min      1.000000         NaN                                 NaN       NaN
# 25%     12.250000         NaN                                 NaN       NaN
# 50%     23.500000         NaN                                 NaN       NaN
# 75%     34.750000         NaN                                 NaN       NaN
# max     46.000000         NaN                                 NaN       NaN
#
#          team2  stage toss_winner toss_decision  first_ings_score  \
# count       46     46          46            46         46.000000
# unique       9      1          10             2               NaN
# top     Punjab  Group   Hyderabad         Field               NaN
# freq         9     46           8            43               NaN
# mean       NaN    NaN         NaN           NaN        171.847826
# std        NaN    NaN         NaN           NaN         30.254452
# min        NaN    NaN         NaN           NaN         68.000000
# 25%        NaN    NaN         NaN           NaN        154.250000
# 50%        NaN    NaN         NaN           NaN        169.500000
# 75%        NaN    NaN         NaN           NaN        194.500000
# max        NaN    NaN         NaN           NaN        222.000000
#
#         first_ings_wkts  second_ings_score  second_ings_wkts match_winner  \
# count         46.000000          46.000000         46.000000           46
# unique              NaN                NaN               NaN           10
# top                 NaN                NaN               NaN      Gujarat
# freq                NaN                NaN               NaN            8
# mean           6.130435         162.847826          6.217391          NaN
# std            2.276534          27.469553          2.529058          NaN
# min            2.000000          72.000000          1.000000          NaN
# 25%            5.000000         150.500000          4.000000          NaN
# 50%            6.000000         162.000000          6.500000          NaN
# 75%            8.000000         178.250000          8.000000          NaN
# max           10.000000         211.000000         10.000000          NaN
#
#          won_by     margin player_of_the_match   top_scorer   highscore  \
# count        46  46.000000                  45           46   46.000000
# unique        2        NaN                  36           30         NaN
# top     Wickets        NaN       Kuldeep Yadav  Jos Buttler         NaN
# freq         24        NaN                   4            5         NaN
# mean        NaN  13.413043                 NaN          NaN   72.369565
# std         NaN  13.478503                 NaN          NaN   19.075707
# min         NaN   3.000000                 NaN          NaN   28.000000
# 25%         NaN   5.250000                 NaN          NaN   58.250000
# 50%         NaN   7.500000                 NaN          NaN   68.000000
# 75%         NaN  15.750000                 NaN          NaN   87.750000
# max         NaN  61.000000                 NaN          NaN  116.000000
#
#             best_bowling best_bowling_figure
# count                 46                  46
# unique                32                  37
# top     Yuzvendra Chahal               3--22
# freq                   4                   3
# mean                 NaN                 NaN
# std                  NaN                 NaN
# min                  NaN                 NaN
# 25%                  NaN                 NaN
# 50%                  NaN                 NaN
# 75%                  NaN                 NaN
# max                  NaN                 NaN

# %% [markdown]
# ## The dataset contains all the information needed to summarize the story of IPL 2022 so far. So let’s start by looking at the number of matches won by each team in IPL 2022:

# %%
plt.figure(figsize=(9,6))
sns.countplot(x='match_winner',data=df)
plt.xticks(rotation=90,size=12)
plt.show()

# %% [raw]
# # alternate countplot with barplot
# plt.figure(figsize=(9,6))
# counts = df['match_winner'].value_counts()
# sns.barplot(x=counts.index, y=counts)
# plt.xlabel('Team',size=14)
# plt.ylabel('Count',size=14)
# plt.xticks(rotation=90,size=12)
# plt.show()

# %% [markdown]
# ## So, currently, Gujrat is leading the tournament by winning eight matches. It is an achievement as a new team for Gujrat in IPL. Now let’s see how most of the teams win. Here we will analyze whether most of the teams win by defending (batting first) or chasing (batting second):

# %%
c_d = df['won_by'].value_counts()
c_d
# Out:
# Wickets    24
# Runs       22
# Name: won_by, dtype: int64

# %%
c_d.rename(index={'Wickets':'Chasing','Runs':'Defending'},inplace=True)

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=c_d.index,y=c_d)
plt.xlabel('Team',size=14)
plt.ylabel('Count',size=14)
plt.xticks(size=12)
plt.yticks(range(0,max(c_d)+2,2),size=10)
plt.show()

# %% [markdown]
# ## So, currently, 24 matches are won while chasing the target, and 22 matches are won while defending the target. Now let’s see what most teams prefer (batting or fielding) after winning the toss:

# %%
td = df['toss_decision'].value_counts()
td
# Out:
# Field    43
# Bat       3
# Name: toss_decision, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=td.index,y=td)
plt.xlabel('Decision',size=14)
plt.ylabel('Count',size=14)
plt.xticks(size=12)
plt.yticks(range(0,max(td)+2,2),size=10)
plt.show()

# %% [markdown]
# ## Thus, most captains choose to field after winning the toss. So far, in 43 games, captains have chosen to field first, and in just three games, the captains have chosen to bat first. Now let’s see the top scorers of most IPL 2022 matches:

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='top_scorer',data=df)
plt.xticks(rotation=90,size=12)
plt.show()

# %% [markdown]
# ## Currently, Jos Buttler has been a top scorer in 5 matches. He is looking in great touch.
# ## Now let’s have a look at the most player of the match awards till now in IPL 2022:

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='player_of_the_match',data=df)
plt.xticks(rotation=90,size=14)
plt.show()

# %% [markdown]
# ## So Kuldeep Yadav is leading in the list of players of the match awards with four matches. It is a great tournament for Kuldeep Yadav this year. Now let’s have a look at the bowlers with the best bowling figures in most of the matches:

# %%
plt.figure(figsize=(12,8))
sns.countplot(x ='best_bowling', data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## You can see Yuzvendra Chahal having the best bowling figures in four matches. So this is a great tournament for Yuzvendra Chahal this year too.
#
# ## Now let’s have a look at whether most of the wickets fall while setting the target or while chasing the target:

# %%
df1 = df.groupby('venue')['first_ings_wkts','second_ings_wkts'].sum()
df1
# Out:
# C:\Users\Abhishek\AppData\Local\Temp/ipykernel_11668/1000195344.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1 = df.groupby('venue')['first_ings_wkts','second_ings_wkts'].sum()
#                                               first_ings_wkts  \
# venue
# Brabourne Stadium, Mumbai                                  77
# Dr DY Patil Sports Academy, Mumbai                         90
# Maharashtra Cricket Association Stadium,Pune               50
# Wankhede Stadium, Mumbai                                   65
#
#                                               second_ings_wkts
# venue
# Brabourne Stadium, Mumbai                                   62
# Dr DY Patil Sports Academy, Mumbai                          86
# Maharashtra Cricket Association Stadium,Pune                64
# Wankhede Stadium, Mumbai                                    74

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
#
#    margin player_of_the_match      top_scorer  highscore      best_bowling  \
# 0       6         Umesh Yadav        MS Dhoni         50      Dwayne Bravo
# 1       4       Kuldeep Yadav    Ishan Kishan         81     Kuldeep Yadav
# 2       5         Odean Smith  Faf du Plessis         88    Mohammed Siraj
# 3       5      Mohammed Shami    Deepak Hooda         55    Mohammed Shami
# 4      61        Sanju Samson   Aiden Markram         57  Yuzvendra Chahal
#
#   best_bowling_figure
# 0               3--20
# 1               3--18
# 2               2--59
# 3               3--25
# 4               3--22

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df1, x=df1.index, y="first_ings_wkts")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df1, x=df1.index, y="second_ings_wkts")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## So in the Wankhede Stadium in Mumbai and MCA Stadium in Pune, most wickets fall while chasing the target. And in the other two stadiums, most wickets fall while setting the target. So this is how you can analyze and summarize the story of IPL 2022 using Python.

# %% [markdown]
# # Summary
# ## So this is how you can perform the task of IPL 2022 analysis using Python. IPL 2022 is going great for Gujrat as a new team this year. Jos Buttler and KL Rahul have been great with the bat, and Yuzvendra Chahal and Kuldeep Yadav have been great with the bowl. I hope you liked this article on IPL 2022 analysis using Python.
